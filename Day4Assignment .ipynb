# %%
string="what we think we become, we are Python programmer"
string.index ('we')
# Out:
# 5

# %%
string.rindex ('we')
# Out:
# 25

# %%
string.index ('we',6,25)
# Out:
# 14

# %%
str1="LETSUPGRADE"
str1.isupper()
# Out:
# True

# %%
str1.islower()
# Out:
# False

# %%
str2="python essential"
str2.islower()
# Out:
# True

# %%
str2.isupper()
# Out:
# False

# %%
str3="Assignment"
str3.islower()
# Out:
# False

# %%
str3.isupper()
# Out:
# False
